# %% [markdown]
# # 环境初始化
# - 安装第三方包
# - 解压数据和 checkpoints

# %%
# 更新库
# !pip install --upgrade paddlenlp
# !pip install pypinyin
# !pip install python-Levenshtein

# 解压、整理数据和 checkpoints
# !unzip -q -d ./data/data118485/ data/data118485/train_dataset.zip
# !unzip -q -d ./data/ data/data118485/checkpoints0.zip
# !unzip -q -d ./data/ data/data118485/checkpoints1.zip
# !unzip -q -d ./data/ data/data118485/checkpoints2.zip
# !unzip -q -d ./data/ data/data118485/checkpoints3.zip
# !cat ./data/data118485/LCQMC/train ./data/data118485/BQ/train ./data/data118485/OPPO/train ./work/generated_samples.txt > ./data/data118485/train.txt
# !cat ./data/data118485/LCQMC/dev   ./data/data118485/BQ/dev   ./data/data118485/OPPO/dev > ./data/data118485/dev.txt
# !cat ./data/data118485/test_B_1118.tsv > ./data/data118485/test.txt

# %% [markdown]
# # 快速预测
# 使用 checkpoint 复现 B 榜成绩

# %%
# !cd work/ && bash predict.sh
# Out:
# [2021-11-25 21:14:02,369] [    INFO] - Downloading https://paddlenlp.bj.bcebos.com/models/transformers/ernie_gram_zh/ernie_gram_zh.pdparams and saved to /home/aistudio/.paddlenlp/models/ernie-gram-zh
# [2021-11-25 21:14:02,370] [    INFO] - Downloading ernie_gram_zh.pdparams from https://paddlenlp.bj.bcebos.com/models/transformers/ernie_gram_zh/ernie_gram_zh.pdparams
# 100%|████████████████████████████████| 583566/583566 [00:10<00:00, 55981.96it/s]
# W1125 21:14:12.971149  1509 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W1125 21:14:12.975451  1509 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# [2021-11-25 21:14:20,447] [    INFO] - Downloading https://paddlenlp.bj.bcebos.com/models/transformers/ernie_gram_zh/vocab.txt and saved to /home/aistudio/.paddlenlp/models/ernie-gram-zh
# ...

# %% [markdown]
# # 训练
# - 先正常训练一次
# - 伪标签迭代三轮
#
# 用少量样本跑过，可以跑通

# %%
# !cd work/ && bash train.sh
# Out:
# 正在处理训练集数据
#
# 正在处理验证集数据
#
# 正在处理测试集数据
# [2021-11-25 21:39:17,985] [    INFO] - Already cached /home/aistudio/.paddlenlp/models/ernie-gram-zh/ernie_gram_zh.pdparams
# W1125 21:39:17.987133  4035 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W1125 21:39:17.991178  4035 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# [2021-11-25 21:39:25,201] [    INFO] - Already cached /home/aistudio/.paddlenlp/models/ernie-gram-zh/vocab.txt
# save model_last
# [2021-11-25 21:39:49,044] [    INFO] - Already cached /home/aistudio/.paddlenlp/models/ernie-gram-zh/ernie_gram_zh.pdparams
# W1125 21:39:49.046113  4183 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W1125 21:39:49.050252  4183 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# ...

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
